# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

import matplotlib.pyplot as plt
import seaborn as sns

# Some plotting config
sns.set(
    context="notebook",
    # style="ticks",
    style="darkgrid",
    font="Times New Roman",
    font_scale=1.5,
)

sns.color_palette("mako", as_cmap=True)
plt.rcParams["figure.figsize"] = (10, 8)
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
# plt.rcParams["xtick.top"] = True
# plt.rcParams["ytick.right"] = True
# plt.rcParams["xtick.bottom"] = True
# plt.rcParams["ytick.left"] = True
plt.rcParams["mathtext.fontset"] = "cm"


import numpy as np
from limepy import limepy

# %%
l = limepy(
    phi0=6,
    g=1,
    mj=[0.25, 0.5, 0.75, 1.0],
    Mj=[1, 1, 1, 1],
    M=1e6,
    rh=6,
    project=True,
    verbose=True,
    delta=0.5,
)
# Out:
#  No G provided, set to default: G = 0.004302
#  Model scaled to: G = 0.004302, M = 1000000.0, rh = 6
#   1; ind=0.5; diff= 6.0e-02; conv= 1; fdiff=  1.622  -0.074  -0.684  -0.863 ; Mjtot=  0.655   0.231   0.079   0.034
#   2; ind=0.5; diff= 3.2e-02; conv= 1; fdiff=  1.127   0.091  -0.488  -0.730 ; Mjtot=  0.532   0.273   0.128   0.068
#   3; ind=0.5; diff= 1.8e-02; conv= 1; fdiff=  0.793   0.157  -0.338  -0.613 ; Mjtot=  0.448   0.289   0.166   0.097
#   4; ind=0.5; diff= 9.9e-03; conv= 1; fdiff=  0.552   0.168  -0.219  -0.502 ; Mjtot=  0.388   0.292   0.195   0.125
#   5; ind=0.5; diff= 5.2e-03; conv= 1; fdiff=  0.377   0.147  -0.132  -0.393 ; Mjtot=  0.344   0.287   0.217   0.152
#   6; ind=0.5; diff= 2.6e-03; conv= 1; fdiff=  0.252   0.116  -0.075  -0.293 ; Mjtot=  0.313   0.279   0.231   0.177
#   7; ind=0.5; diff= 1.3e-03; conv= 1; fdiff=  0.166   0.084  -0.041  -0.209 ; Mjtot=  0.292   0.271   0.240   0.198
#   8; ind=0.5; diff= 5.7e-04; conv= 1; fdiff=  0.108   0.059  -0.023  -0.145 ; Mjtot=  0.277   0.265   0.244   0.214
#   9; ind=0.5; diff= 2.5e-04; conv= 1; fdiff=  0.070   0.040  -0.012  -0.098 ; Mjtot=  0.268   0.260   0.247   0.226
#  10; ind=0.5; diff= 1.1e-04; conv= 1; fdiff=  0.045   0.027  -0.007  -0.065 ; Mjtot=  0.261   0.257   0.248   0.234
#  11; ind=0.5; diff= 4.7e-05; conv= 1; fdiff=  0.029   0.017  -0.004  -0.043 ; Mjtot=  0.257   0.254   0.249   0.239
#  12; ind=0.5; diff= 2.0e-05; conv= 1; fdiff=  0.019   0.011  -0.002  -0.028 ; Mjtot=  0.255   0.253   0.249   0.243
#  13; ind=0.5; diff= 8.2e-06; conv= 1; fdiff=  0.012   0.007  -0.001  -0.018 ; Mjtot=  0.253   0.252   0.250   0.245
#  14; ind=0.5; diff= 3.4e-06; conv= 1; fdiff=  0.008   0.005  -0.001  -0.012 ; Mjtot=  0.252   0.251   0.250   0.247
#  15; ind=0.5; diff= 1.4e-06; conv= 1; fdiff=  0.005   0.003  -0.000  -0.008 ; Mjtot=  0.251   0.251   0.250   0.248
#  16; ind=0.5; diff= 5.9e-07; conv= 1; fdiff=  0.003   0.002  -0.000  -0.005 ; Mjtot=  0.251   0.250   0.250   0.249
#  17; ind=0.5; diff= 2.4e-07; conv= 1; fdiff=  0.002   0.001  -0.000  -0.003 ; Mjtot=  0.251   0.250   0.250   0.249
#  18; ind=0.5; diff= 1.0e-07; conv= 1; fdiff=  0.001   0.001  -0.000  -0.002 ; Mjtot=  0.250   0.250   0.250   0.249
#  19; ind=0.5; diff= 4.2e-08; conv= 1; fdiff=  0.001   0.001  -0.000  -0.001 ; Mjtot=  0.250   0.250   0.250   0.250
#  20; ind=0.5; diff= 1.7e-08; conv= 1; fdiff=  0.001   0.000  -0.000  -0.001 ; Mjtot=  0.250   0.250   0.250   0.250
#  21; ind=0.5; diff= 7.2e-09; conv= 1; fdiff=  0.000   0.000  -0.000  -0.001 ; Mjtot=  0.250   0.250   0.250   0.250
#
#  Model properties:
#  -----------------
#  phi0 =  6.00; g = 1.00
#  Converged = True
#  M =  1.000e+06; U = -3.422e+08; K = 1.711e+08; Q = 0.5000;  2Kr/Kt = 1.000
#  rv/rh = 1.048; rh/r0 = 25.028; rt/r0 = 142.952; ra/rh = 3995476.901

# %%
plt.figure()

plt.plot(l.r, np.sqrt(l.v2pj[0]), label=r"$m_j=0.25 \ \mathrm{M}_\odot$", lw=2)
plt.plot(l.r, np.sqrt(l.v2pj[1]), label=r"$m_j=0.50 \ \mathrm{M}_\odot$", lw=2)
plt.plot(l.r, np.sqrt(l.v2pj[2]), label=r"$m_j=0.75 \ \mathrm{M}_\odot$", lw=2)
plt.plot(l.r, np.sqrt(l.v2pj[3]), label=r"$m_j=1.00 \ \mathrm{M}_\odot$", lw=2)
plt.xlabel(r"R [pc]")
plt.ylabel(r"$\sigma_{los}$ [km/s]")
plt.xlim(0.1, 35)
plt.ylim(0, 25)
plt.semilogx()
plt.legend()

# %%
plt.figure()
l.multi
plt.plot(l.r, l.rhoj[0], label=r"$m_j=0.25 \ \mathrm{M}_\odot$", lw=2)
plt.plot(l.r, l.rhoj[1], label=r"$m_j=0.50 \ \mathrm{M}_\odot$", lw=2)
plt.plot(l.r, l.rhoj[2], label=r"$m_j=0.75 \ \mathrm{M}_\odot$", lw=2)
plt.plot(l.r, l.rhoj[3], label=r"$m_j=1.00 \ \mathrm{M}_\odot$", lw=2)
plt.xlabel(r"R [pc]")
plt.ylabel(r"Density $[ \mathrm{M}_\odot/\mathrm{pc}^3]$")
plt.xlim(0.1, 35)
plt.ylim(0.1, 1e6)
plt.semilogx()
plt.semilogy()

plt.legend()

# %%
l.mcj.shape
# Out:
# (4, 82)

# %%
l.r.shape
# Out:
# (82,)

# %%
l.rt
# Out:
# 34.26969388614078

# %%
plt.rcParams.update(
    {
        "text.usetex": True,
    }
)

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 8))


axes[0].plot(l.r, np.sqrt(l.v2pj[0]), label=r"$m_j=0.25 \ \mathrm{M}_\odot$", lw=2)
axes[0].plot(l.r, np.sqrt(l.v2pj[1]), label=r"$m_j=0.50 \ \mathrm{M}_\odot$", lw=2)
axes[0].plot(l.r, np.sqrt(l.v2pj[2]), label=r"$m_j=0.75 \ \mathrm{M}_\odot$", lw=2)
axes[0].plot(l.r, np.sqrt(l.v2pj[3]), label=r"$m_j=1.00 \ \mathrm{M}_\odot$", lw=2)
axes[0].set_xlabel(r"R [pc]")
axes[0].set_ylabel(r"$\sigma_{los}$ [km/s]")
axes[0].set_xlim(0.05, 35)
axes[0].set_ylim(1, 25)
axes[0].semilogx()
axes[0].legend()


axes[1].plot(l.r, l.rhoj[0], label=r"$m_j=0.25 \ \mathrm{M}_\odot$", lw=2)
axes[1].plot(l.r, l.rhoj[1], label=r"$m_j=0.50 \ \mathrm{M}_\odot$", lw=2)
axes[1].plot(l.r, l.rhoj[2], label=r"$m_j=0.75 \ \mathrm{M}_\odot$", lw=2)
axes[1].plot(l.r, l.rhoj[3], label=r"$m_j=1.00 \ \mathrm{M}_\odot$", lw=2)
axes[1].set_xlabel(r"R [pc]")
axes[1].set_ylabel(r"Density $[ \mathrm{M}_\odot/\mathrm{pc}^3]$")
axes[1].set_xlim(0.05, 35)
axes[1].set_ylim(1, 10 ** (6.5))
axes[1].semilogx()
axes[1].semilogy()

plt.legend()
fig.tight_layout()
fig.savefig("limepy_demo.png", dpi=300)
